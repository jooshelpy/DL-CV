# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.0/617.0 kB 8.4 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/MIA/Task_8_3/Coins.zip
# Out:
# Archive:  /content/drive/MyDrive/MIA/Task_8_3/Coins.zip
#    creating: Coins/train/
#    creating: Coins/train/images/
#   inflating: Coins/train/images/v1_coins_no_1.jpg
#   inflating: Coins/train/images/v1_coins_no_10.jpg
#   inflating: Coins/train/images/v1_coins_no_100.jpg
#   inflating: Coins/train/images/v1_coins_no_102.jpg
#   inflating: Coins/train/images/v1_coins_no_103.jpg
#   inflating: Coins/train/images/v1_coins_no_104.jpg
#   inflating: Coins/train/images/v1_coins_no_105.jpg
#   inflating: Coins/train/images/v1_coins_no_106.jpg
#   inflating: Coins/train/images/v1_coins_no_107.jpg
#   inflating: Coins/train/images/v1_coins_no_108.jpg
#   inflating: Coins/train/images/v1_coins_no_109.jpg
#   inflating: Coins/train/images/v1_coins_no_11.jpg
#   inflating: Coins/train/images/v1_coins_no_110.jpg
#   inflating: Coins/train/images/v1_coins_no_111.jpg
#   inflating: Coins/train/images/v1_coins_no_112.jpg
#   inflating: Coins/train/images/v1_coins_no_113.jpg
# ...

# %%
# %cd /content/drive/MyDrive/MIA/Task_8_3
# Out:
# /content/drive/MyDrive/MIA/Task_8_3

# %%
# !yolo task=detect mode=train data=/content/coins.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
